# %%
print(7)
# Out:
# 7

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
sentence="this is the common sentence. which is the test sentences"

word_tokenize(sentence)
# Out:
# ['this',
#  'is',
#  'the',
#  'common',
#  'sentence',
#  '.',
#  'which',
#  'is',
#  'the',
#  'test',
#  'sentences']
