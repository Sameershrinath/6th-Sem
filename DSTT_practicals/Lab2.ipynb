# %%
import numpy as np

# Discrete Distribution (Binomial)
binomial = np.random.binomial(n=10, p=0.5, size=8)

# Continuous Distribution (Normal)
normal = np.random.normal(loc=50, scale=5, size=10)

print("Binomial Distribution:", binomial)
print("Normal Distribution:", normal)
# Out:
# Binomial Distribution: [3 3 6 7 4 7 3 7]
# Normal Distribution: [56.05185114 51.11308321 42.18923317 51.26460599 55.22070569 53.89762834
#  51.68526246 54.35530006 38.78084739 52.90728054]
